# %%
import random
import json
import requests
import pandas as pd
import configparser
import matplotlib.pyplot as plt
import gmaps
from pprint import pprint
config = configparser.ConfigParser()
#config.read('../../API_keys/config.py')
config.read('../../../API_keys/config.py')
gkey = config['DEFAULT']['G_KEY']
gmaps.configure(api_key=gkey)

# %%
cities_df = pd.read_csv('../Resources/Cities_dataframe.csv')
cities_df.dropna(inplace = True) 
cities_df.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    chokurdakh  70.63  147.92     34.95        96          38       14.94
# 1    nikolskoye  59.70   30.79     55.40        82          20        6.71
# 2         bluff -46.60  168.33     37.99        94          61        3.00
# 3  punta arenas -53.15  -70.92     37.40        59          75       35.57
# 4          faya  18.39   42.45     69.80        64          14        5.82
#
#   Country        Date
# 0      RU  1601488077
# 1      RU  1601488077
# 2      NZ  1601488077
# 3      CL  1601487894
# 4      SA  1601488078

# %%
locations = cities_df[["Lat", "Lng"]]
humidity = cities_df["Humidity"].astype(float)

# %%
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=10, point_radius=1)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
ideal_cities_df = cities_df.loc[cities_df["Max Temp"] < 80]
ideal_cities_df = ideal_cities_df.loc[ideal_cities_df["Max Temp"] > 70]
ideal_cities_df = ideal_cities_df.loc[ideal_cities_df["Cloudiness"] == 0]
ideal_cities_df = ideal_cities_df.reset_index(drop=True)
ideal_cities_df
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  nouadhibou  20.93  -17.03     77.00        69           0       19.46
# 1    portland  45.52 -122.68     72.00        63           0        1.01
# 2   mount isa -20.73  139.50     78.80        24           0       14.99
# 3    bardiyah  31.76   25.09     73.04        76           0       12.66
# 4    karratha -20.74  116.85     71.40        47           0        7.49
# 5    sai buri   6.70  101.62     78.46        84           0        3.56
# 6    benghazi  32.12   20.07     75.33        65           0       14.43
# 7      lardos  36.09   28.02     75.20        53           0       14.99
# 8   salamiyah  35.01   37.05     71.55        78           0       13.27
#
#   Country        Date
# 0      MR  1601488093
# 1      US  1601487971
# 2      AU  1601488126
# 3      LY  1601488139
# 4      AU  1601488154
# 5      TH  1601488167
# 6      LY  1601487967
# 7      GR  1601488014
# 8      SY  1601488233

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
ideal_cities_df_countries = ideal_cities_df["Country"]
ideal_cities_df_countries
# Out:
# 0    MR
# 1    US
# 2    AU
# 3    LY
# 4    AU
# 5    TH
# 6    LY
# 7    GR
# 8    SY
# Name: Country, dtype: object

# %%
# locations_ideal = ideal_cities_df[["Lat", "Lng"]]
# markers_ideal = gmaps.marker_layer(locations_ideal)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#create a dataframe

hotel_df = ideal_cities_df[["City","Lat","Lng"]]
hotel_df
# Out:
#          City    Lat     Lng
# 0  nouadhibou  20.93  -17.03
# 1    portland  45.52 -122.68
# 2   mount isa -20.73  139.50
# 3    bardiyah  31.76   25.09
# 4    karratha -20.74  116.85
# 5    sai buri   6.70  101.62
# 6    benghazi  32.12   20.07
# 7      lardos  36.09   28.02
# 8   salamiyah  35.01   37.05

# %%
hotel_df['Hotel Name'] = ""
hotel_df['Address'] = ""
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Out:
#          City    Lat     Lng Hotel Name Address
# 0  nouadhibou  20.93  -17.03
# 1    portland  45.52 -122.68
# 2   mount isa -20.73  139.50
# 3    bardiyah  31.76   25.09
# 4    karratha -20.74  116.85
# 5    sai buri   6.70  101.62
# 6    benghazi  32.12   20.07
# 7      lardos  36.09   28.02
# 8   salamiyah  35.01   37.05

# %%
 for index, row in hotel_df.iterrows():   
    first = hotel_df.iloc[index,1]
    second = hotel_df.iloc[index,2]
    print(first)
    print(second)
# Out:
# 20.93
# -17.03
# 45.52
# -122.68
# -20.73
# 139.5
# 31.76
# 25.09
# -20.74
# 116.85
# 6.7
# 101.62
# 32.12
# 20.07
# 36.09
# 28.02
# 35.01
# 37.05

# %%
first = hotel_df.iloc[0,1]
first
# Out:
# 20.93

# %%
second = hotel_df.iloc[0,2]
second
# Out:
# -17.03

# %%
# need to fiddle with the target coordinates from the dataframe

target_coordinates = f"{first},{second}"
target_coordinates
# Out:
# '20.93,-17.03'

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": target_coordinates,  # philadelphia coords,
    "type": "lodging",
    "radius": 5000,
    "key": gkey,
}

response = requests.get(base_url, params=params).json()
pprint(response)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CqQCHAEAAAkmObHsciclRuZq0Qz6xhHBHoD_L0xgeY5_hPnxzkJarNoQ37ehZnIwvW0TNU4v3NKO8oGTJkfIWzBhX1MtpNXSZe6pvwhN9rOO4C0btCy4ZtxTo1UucwsksivuAGIy7Y29gVptZYPH3Q4mx2HHpnenm7T8JcniiqqSAlq7K8hsDtsR66_aSoy3zRg5nUlEPums5NgWTFIDMt6tL1xUhagC0wFaQcU9ouw6PvJjlEDyJLARFEXB3GfCwWF3UVxeuKg7c0g6jurEVtWx2oYPlGldiDbhCToEZpoJsL-L8P4w0N5yeJ8Li1f6scm9H0drrSqw5kV_Kv0p09acphuD5enoTHbxn-9-Wj7MaLij6JIHnIzwcMpVF-WtPq9hw_h0ChIQvCcZJGTTf1QYzWqrF3y6xBoUvEFYQxhywQdOrvJC5STO-PIbiLM',
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 20.9129169, 'lng': -17.0277599},
#                            'viewport': {'northeast': {'lat': 20.9148863302915,
#                                                       'lng': -17.0267098197085},
#                                         'southwest': {'lat': 20.9121883697085,
#                                                       'lng': -17.0294077802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'name': 'El Medina',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4608,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106255056234273850128">Vicente '
#                                                 'Ruiz</a>'],
#                           'photo_reference': 'CmRaAAAAmDIHlfy_HsICjZtNvWUQ-m8mGUfq23krEtHhu5rbOAHRB9GEUbsz7ziAq7HQTIEufFvRJWk12-AaNapZ9o13ryOFTe6SalgcbS5g_buwy0eMGvqji7Mfl0X8COYdfDW8EhBpca2SMuvZja6eYzb2TScrGhR0oOqVVmHi-VyrgWtS0PC9YxVT_g',
#                           'width': 3456}],
#               'place_id': 'ChIJXQcq5-qzoQ4Rt68NL9y2KbU',
#               'plus_code': {'compound_code': 'WX7C+5V Nouadhibou, Mauritania',
#                             'global_code': '7CG4WX7C+5V'},
#               'rating': 4,
#               'reference': 'ChIJXQcq5-qzoQ4Rt68NL9y2KbU',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 10,
#               'vicinity': 'zone dubai ext.p5 lot 72. BP. 4350, Nouadhibou'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 20.9370371, 'lng': -17.0338099},
#                            'viewport': {'northeast': {'lat': 20.9383853302915,
#                                                       'lng': -17.0324947697085},
#                                         'southwest': {'lat': 20.93568736970849,
#                                                       'lng': -17.0351927302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'name': 'Apparts Hotel Esma',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1700,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103005735201137401132">Diego '
#                                                 'Roel</a>'],
#                           'photo_reference': 'CmRaAAAAZzm7WiKJhJvG3Ya8WDy5baiODk-ZGJCerwIDYnFEwUZVhWlxNVoSJZwb5wZqCOIWz4Fyk0iy0YYf9YQsPMeUSx9CISpxvEJAi2zNOqs4OsRN39GFMs98_w-Ij4GOpT2GEhDSPgXZ6gSTx4GQcXULqDfgGhRSi-YDrX8UH36oHp6yc_2jJLgoaw',
#                           'width': 3443}],
#               'place_id': 'ChIJL_hxQgyzoQ4RPWiDFyKOv8U',
#               'plus_code': {'compound_code': 'WXP8+RF Nouadhibou, Mauritania',
#                             'global_code': '7CG4WXP8+RF'},
#               'rating': 4.1,
#               'reference': 'ChIJL_hxQgyzoQ4RPWiDFyKOv8U',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 22,
#               'vicinity': 'Unnamed Rd, Nouadhibou'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 20.9254741, 'lng': -17.0403252},
#                            'viewport': {'northeast': {'lat': 20.9268427802915,
#                                                       'lng': -17.0389628697085},
#                                         'southwest': {'lat': 20.9241448197085,
#                                                       'lng': -17.0416608302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'name': 'Hôtel Prestige',
#               'photos': [{'height': 1365,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115431489627295674260">Abdou '
#                                                 'ould isselmou</a>'],
#                           'photo_reference': 'CmRaAAAAU3a8gBwzGOgN5_3xhyOpAYvsFQcNrbMj4DBhtVI4dHoKVKGXS4VfO6nykUPg6OVwQaoxDnaNlrJMwoDax5Y8epP7nIe1zv5LZfrzPEvh8-rB8_ImyCjQJMqjYZIuhR9MEhDNNBvyZckuZble-iQ7IvdzGhSVWi_580Z0FR06EdMTSddM7V4Etw',
#                           'width': 2048}],
#               'place_id': 'ChIJ36oEOKWzoQ4Rf0NKqiumz6k',
#               'plus_code': {'compound_code': 'WXG5+5V Nouadhibou, Mauritania',
#                             'global_code': '7CG4WXG5+5V'},
#               'rating': 4.1,
#               'reference': 'ChIJ36oEOKWzoQ4Rf0NKqiumz6k',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 20,
#               'vicinity': 'boulebard maritime, Nouadhibou'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 20.9213625, 'lng': -17.0426394},
#                            'viewport': {'northeast': {'lat': 20.9228348302915,
#                                                       'lng': -17.0412554197085},
#                                         'southwest': {'lat': 20.9201368697085,
#                                                       'lng': -17.0439533802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'name': 'HOtel Tasiast',
#               'photos': [{'height': 1960,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101225533008456979506">Tran '
#                                                 'Toan</a>'],
#                           'photo_reference': 'CmRaAAAAKWWQc-sF8dSUsAxdojF73p73J5sAH-nFH5wl_ioCjgQ2TmjtRxuZimAYFxy38dJPs3WNSG3N8pa3QYdsdcRUitJi48ym5_-FejdgVxE2h3o2eBkToF_Jl-K040HyF6nrEhAgfy5RDoDmsIb00CJIvwvcGhRQDVBXC99wMpLwYRgXmXDtTIJgQA',
#                           'width': 4032}],
#               'place_id': 'ChIJowrumrCzoQ4RGJf6EPWZDJ0',
#               'plus_code': {'compound_code': 'WXC4+GW Nouadhibou, Mauritania',
#                             'global_code': '7CG4WXC4+GW'},
#               'rating': 4.1,
#               'reference': 'ChIJowrumrCzoQ4RGJf6EPWZDJ0',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 62,
#               'vicinity': 'Nouadhibou'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 20.93177349999999,
#                                         'lng': -17.0343574},
#                            'viewport': {'northeast': {'lat': 20.9331020802915,
#                                                       'lng': -17.0329325697085},
#                                         'southwest': {'lat': 20.93040411970849,
#                                                       'lng': -17.0356305302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'name': 'Appartement',
#               'opening_hours': {'open_now': True},
#               'place_id': 'ChIJwT1qP3-zoQ4RRw2UIadBwKk',
#               'plus_code': {'compound_code': 'WXJ8+P7 Nouadhibou, Mauritania',
#                             'global_code': '7CG4WXJ8+P7'},
#               'reference': 'ChIJwT1qP3-zoQ4RRw2UIadBwKk',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'vicinity': 'Nouadhibou'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 20.9355094,
#                                         'lng': -17.03160129999999},
#                            'viewport': {'northeast': {'lat': 20.9369015802915,
#                                                       'lng': -17.03025406970849},
#                                         'southwest': {'lat': 20.9342036197085,
#                                                       'lng': -17.0329520302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'name': 'Résidence lkhaima',
#               'photos': [{'height': 1080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108864540185741853687">Moh '
#                                                 'hacen Ghotoub</a>'],
#                           'photo_reference': 'CmRaAAAAZeqzw49wZzN-QKbnA3YL_SJkYH88F93S79skKdAqM_C-BuF6030zE9P7MLUd6ohwzr0697u90l9fvjkep453DrMtxRk1wTs5-qzRneIw6sI9tpkyP5j0FlPvBdZY6TB8EhDT3ffRJZBYpvPC8ixHY8cfGhRJTlHQisRokdTALYwdpJAMZSNr7w',
#                           'width': 1920}],
#               'place_id': 'ChIJ06S4_zOzoQ4RKjHb0HO_u_8',
#               'plus_code': {'compound_code': 'WXP9+69 Nouadhibou, Mauritania',
#                             'global_code': '7CG4WXP9+69'},
#               'rating': 3,
#               'reference': 'ChIJ06S4_zOzoQ4RKjHb0HO_u_8',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'Dubai, Unnamed Road, Mauritanie Nouadhibou'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 20.9332387, 'lng': -17.0352174},
#                            'viewport': {'northeast': {'lat': 20.9346087302915,
#                                                       'lng': -17.0339535197085},
#                                         'southwest': {'lat': 20.9319107697085,
#                                                       'lng': -17.0366514802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'name': 'Hotel Taïba',
#               'place_id': 'ChIJBQDbrN6zoQ4R-OYOz4DN6uY',
#               'plus_code': {'compound_code': 'WXM7+7W Nouadhibou, Mauritania',
#                             'global_code': '7CG4WXM7+7W'},
#               'rating': 5,
#               'reference': 'ChIJBQDbrN6zoQ4R-OYOz4DN6uY',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'Nouadhibou'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 20.9352109, 'lng': -17.0329895},
#                            'viewport': {'northeast': {'lat': 20.9365337302915,
#                                                       'lng': -17.0316389697085},
#                                         'southwest': {'lat': 20.93383576970849,
#                                                       'lng': -17.0343369302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'name': 'Appartements Nour',
#               'opening_hours': {'open_now': True},
#               'place_id': 'ChIJBwjI6HKzoQ4RnGf4USrSDa8',
#               'plus_code': {'compound_code': 'WXP8+3R Nouadhibou, Mauritania',
#                             'global_code': '7CG4WXP8+3R'},
#               'rating': 4,
#               'reference': 'ChIJBwjI6HKzoQ4RnGf4USrSDa8',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 3,
#               'vicinity': 'Unnamed Road'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 20.9355588, 'lng': -17.0321835},
#                            'viewport': {'northeast': {'lat': 20.9368927302915,
#                                                       'lng': -17.0308339197085},
#                                         'southwest': {'lat': 20.9341947697085,
#                                                       'lng': -17.0335318802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'name': 'Résidence lkhaima',
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116001246821244628414">eddouha '
#                                                 'mohamed</a>'],
#                           'photo_reference': 'CmRaAAAA4c4r0ahg9wMBnTBr06CxSbC8Vceq8_ZhbUNHngBf2uZzuTJVkLHYpzb76r43JSkee6ZG9Eb-Yf48wXLYqZjsi2VRRIbGyxhpAlzYAcN5r4hV-sA1W7_OPQEjWk7iR-2QEhDdVR7pK5Qvt5EdP-oAwt9cGhSustTrQx_bzR8YKC5GHx98KLrZ-Q',
#                           'width': 4032}],
#               'place_id': 'ChIJPwoMPNuzoQ4RyuN4hszWQ8o',
#               'plus_code': {'compound_code': 'WXP9+64 Nouadhibou, Mauritania',
#                             'global_code': '7CG4WXP9+64'},
#               'rating': 2,
#               'reference': 'ChIJPwoMPNuzoQ4RyuN4hszWQ8o',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 2,
#               'vicinity': 'Unnamed Road'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 20.9340695, 'lng': -17.0352647},
#                            'viewport': {'northeast': {'lat': 20.9354062302915,
#                                                       'lng': -17.0338706697085},
#                                         'southwest': {'lat': 20.9327082697085,
#                                                       'lng': -17.0365686302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'name': 'شقق المطار',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4160,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101744045860898363501">sayed '
#                                                 'ahmed</a>'],
#                           'photo_reference': 'CmRaAAAAaL1ci8R8D7WNg5blk7J9mppke4eAm8_VDfrdgAhDk6T5vNI_-e-UProTzPCiIlyGu4QjNVzF_SU_p2mcXm24NTtUEqbxiVA1gxtFijPX0ljlD5nly3nODyciH4_0Em26EhAyVIePYel3n70AT7-kDksIGhRxdDD8C_jkZo13FAjD7uU71tRbTg',
#                           'width': 3120}],
#               'place_id': 'ChIJD1cd_PKzoQ4RCIyaciuvtvc',
#               'plus_code': {'compound_code': 'WXM7+JV Nouadhibou, Mauritania',
#                             'global_code': '7CG4WXM7+JV'},
#               'rating': 4.7,
#               'reference': 'ChIJD1cd_PKzoQ4RCIyaciuvtvc',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 3,
#               'vicinity': 'Unnamed Road'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 20.9353405, 'lng': -17.0337928},
#                            'viewport': {'northeast': {'lat': 20.9367789802915,
#                                                       'lng': -17.0324470697085},
#                                         'southwest': {'lat': 20.9340810197085,
#                                                       'lng': -17.03514503029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'name': 'شقق الديار المفروشه Appartement DIAR',
#               'photos': [{'height': 552,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106305840957065566934">Ethmane '
#                                                 'Elmahjoub</a>'],
#                           'photo_reference': 'CmRaAAAA0FFMwkJkFiHzwvi3oJqAFq1gUsco0T4DDo2MZ_KGsmEdaXrZM9HYiWr1rD1G6fQqvzBhmzrsdHe7WmtW1ftjTMZUBLX2xsyAobmRIIUZbY6d9ANvM8EP-8TT46J68nTnEhCRDNPyRS5jsgwGg4UVCEFbGhTKDJHEjL9P2c-1IXVDiW2usS2KKQ',
#                           'width': 914}],
#               'place_id': 'ChIJfWRT0z6zoQ4Rfwox1EeBs8c',
#               'plus_code': {'compound_code': 'WXP8+4F Nouadhibou, Mauritania',
#                             'global_code': '7CG4WXP8+4F'},
#               'rating': 3.5,
#               'reference': 'ChIJfWRT0z6zoQ4Rfwox1EeBs8c',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 2,
#               'vicinity': 'Nouadhibou'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 20.9363715, 'lng': -17.0324063},
#                            'viewport': {'northeast': {'lat': 20.9377199302915,
#                                                       'lng': -17.0310811197085},
#                                         'southwest': {'lat': 20.93502196970849,
#                                                       'lng': -17.0337790802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'name': 'Appartement El Oumara',
#               'place_id': 'ChIJL50pcu2zoQ4R8YRmqeroHOg',
#               'plus_code': {'compound_code': 'WXP9+G2 Nouadhibou, Mauritania',
#                             'global_code': '7CG4WXP9+G2'},
#               'reference': 'ChIJL50pcu2zoQ4R8YRmqeroHOg',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'vicinity': 'نواذيبو،،, Nouadhibou'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 20.9359953, 'lng': -17.0337123},
#                            'viewport': {'northeast': {'lat': 20.9373421302915,
#                                                       'lng': -17.0324216697085},
#                                         'southwest': {'lat': 20.93464416970849,
#                                                       'lng': -17.0351196302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'name': 'شقق السرور Residence Sourour',
#               'place_id': 'ChIJzeaCmF-zoQ4R5VS00S3SqVY',
#               'plus_code': {'compound_code': 'WXP8+9G Nouadhibou, Mauritania',
#                             'global_code': '7CG4WXP8+9G'},
#               'rating': 3,
#               'reference': 'ChIJzeaCmF-zoQ4R5VS00S3SqVY',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'Nouadhibou'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 20.9359377, 'lng': -17.0340325},
#                            'viewport': {'northeast': {'lat': 20.9372904802915,
#                                                       'lng': -17.0325808197085},
#                                         'southwest': {'lat': 20.9345925197085,
#                                                       'lng': -17.03527878029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'name': 'Appartements ejewhara',
#               'photos': [{'height': 4160,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100914253698792743647">أحمدو '
#                                                 'سالم</a>'],
#                           'photo_reference': 'CmRaAAAA-l88raGDFir19HzHsTOwk_MF8Su0Kw43kDINVU_eXOWuzaAZQlGciw_oasGz8TyN99P0KXCEJkvD7e_zC803SCx_QsfZskK3JkAEFjs-fqMEic7YV1QHsa-L5wIrWXnmEhAPeM3-8AEr-vDIeHdFOW_2GhQjPQb-evPoTl966GnNekpJMm9cEg',
#                           'width': 3120}],
#               'place_id': 'ChIJoTcseUyzoQ4R9KycdgJrAQQ',
#               'plus_code': {'compound_code': 'WXP8+99 Nouadhibou, Mauritania',
#                             'global_code': '7CG4WXP8+99'},
#               'reference': 'ChIJoTcseUyzoQ4R9KycdgJrAQQ',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'vicinity': 'Nouadhibou'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 20.9361002,
#                                         'lng': -17.03410329999999},
#                            'viewport': {'northeast': {'lat': 20.9374541802915,
#                                                       'lng': -17.0326197197085},
#                                         'southwest': {'lat': 20.9347562197085,
#                                                       'lng': -17.0353176802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'name': 'Rèsidence Dubai إقامة دبي',
#               'place_id': 'ChIJefpGNAuzoQ4RdEbVe3q4Fh0',
#               'plus_code': {'compound_code': 'WXP8+C9 Nouadhibou, Mauritania',
#                             'global_code': '7CG4WXP8+C9'},
#               'rating': 3,
#               'reference': 'ChIJefpGNAuzoQ4RdEbVe3q4Fh0',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'Nouadhibou'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 20.9359828, 'lng': -17.0352975},
#                            'viewport': {'northeast': {'lat': 20.9372131302915,
#                                                       'lng': -17.0339445197085},
#                                         'southwest': {'lat': 20.9345151697085,
#                                                       'lng': -17.0366424802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'name': 'شقق انواذيب المفروشة',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113095518187497350168">ahmed '
#                                                 'chbih</a>'],
#                           'photo_reference': 'CmRaAAAAoH7untwbR-C34Ww1nutKZAgJxhMZPwDhTtytkYUbdJ14Wddzk-HTLoTfK3fVrayGE_9AyjY0DTCGfZpv1hnuZ9gP9C7sN5E11y_LGolJNGiGgWfI2qfegDWO1QNnuK10EhCIm6Rs_frjj9kSNv5qXjxxGhS4KiSCsWzx06j4QFE-65MSWykd_w',
#                           'width': 810}],
#               'place_id': 'ChIJ45fhqz2zoQ4RBwVFv8rQXKU',
#               'plus_code': {'compound_code': 'WXP7+9V Nouadhibou, Mauritania',
#                             'global_code': '7CG4WXP7+9V'},
#               'rating': 5,
#               'reference': 'ChIJ45fhqz2zoQ4RBwVFv8rQXKU',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'شقق نواذيبو المفروشة، ،'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 20.9367071, 'lng': -17.0348218},
#                            'viewport': {'northeast': {'lat': 20.9380861802915,
#                                                       'lng': -17.0334728197085},
#                                         'southwest': {'lat': 20.9353882197085,
#                                                       'lng': -17.0361707802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'name': 'Marbella Suite Nouadhibou',
#               'photos': [{'height': 2268,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107866782679064014408">SIDI '
#                                                 'ABEIDNA</a>'],
#                           'photo_reference': 'CmRaAAAA65D-k2BQEUxEYU8fElwqRRDhwMNyhg64rIR0F2D_07kUrW8-U7hz5wseXxC_JF1-GWepNJGQHa3Jl_cHsAX7HNseqJi7TJG3SHx0v-MCxWAliGQv62Xu3-Xd5lS9140QEhCd1NjnXcW6Wp6X6k5vWd7RGhSjfuFa5wBsxkUEN_JUKLADc18zMg',
#                           'width': 4032}],
#               'place_id': 'ChIJDwrETIOzoQ4R9ot-V9LHbos',
#               'plus_code': {'compound_code': 'WXP8+M3 Nouadhibou, Mauritania',
#                             'global_code': '7CG4WXP8+M3'},
#               'rating': 4.5,
#               'reference': 'ChIJDwrETIOzoQ4R9ot-V9LHbos',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 2,
#               'vicinity': 'Nouadhibou'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 20.9384556, 'lng': -17.0341606},
#                            'viewport': {'northeast': {'lat': 20.9398077302915,
#                                                       'lng': -17.0326928197085},
#                                         'southwest': {'lat': 20.9371097697085,
#                                                       'lng': -17.0353907802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'name': 'شقق ميمونة Appartements Meimouna',
#               'photos': [{'height': 1080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106305840957065566934">Ethmane '
#                                                 'Elmahjoub</a>'],
#                           'photo_reference': 'CmRaAAAAK-eqPgAVQbSsgcuiZj4kzz_3yKPRipKwnyPQLwJxzA6ppfmFhj1xz_66Bg_nmD-aZoWRGw1jfed33XWcy6x00ZwPK0Mu6FJcjRLdaRRYg0FARgErZrCTQu0TccpxP6yfEhBgLmMXYy6VcCgFAnZeA5CuGhRhNSFvXUNKV_stWFWYZnlCFPXTSQ',
#                           'width': 1920}],
#               'place_id': 'ChIJ712TplezoQ4RtmnwuzAqbPM',
#               'plus_code': {'compound_code': 'WXQ8+98 Nouadhibou, Mauritania',
#                             'global_code': '7CG4WXQ8+98'},
#               'rating': 4,
#               'reference': 'ChIJ712TplezoQ4RtmnwuzAqbPM',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'Nouadhibou'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 20.9288279, 'lng': -17.0399401},
#                            'viewport': {'northeast': {'lat': 20.9301936302915,
#                                                       'lng': -17.0385054697085},
#                                         'southwest': {'lat': 20.9274956697085,
#                                                       'lng': -17.0412034302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'name': 'Appartement Sultan',
#               'photos': [{'height': 3264,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116920517833200467338">Medlemine '
#                                                 'Soultan</a>'],
#                           'photo_reference': 'CmRZAAAANeVkT591Nvs-yonP5JLipbNZl6HJ0sT_xjnOUAorU0ShKEKrIR686XjqbFSaLMTNJo4Gjd6LIu2axFX9gWHsGgAWFhJ9lhvC1vqh5SwL1bkzSPy7cuqvZvuf32J8oUR0EhACV21tS84iYmAeKK1JESyOGhSE6T0vBTV8JtsCJNMshrJeWRmV9g',
#                           'width': 2448}],
#               'place_id': 'ChIJq94lzpezoQ4RbzYnKcGJck4',
#               'plus_code': {'compound_code': 'WXH6+G2 Nouadhibou, Mauritania',
#                             'global_code': '7CG4WXH6+G2'},
#               'rating': 5,
#               'reference': 'ChIJq94lzpezoQ4RbzYnKcGJck4',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 2,
#               'vicinity': 'c17 a coté du premier classe transport, Nouadhibou'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 20.9386535, 'lng': -17.034453},
#                            'viewport': {'northeast': {'lat': 20.93999928029151,
#                                                       'lng': -17.0331951197085},
#                                         'southwest': {'lat': 20.9373013197085,
#                                                       'lng': -17.0358930802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'name': 'HOTEL VALENCIA',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 4608,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/118004078752878062305">Maciej '
#                                                 'Gross</a>'],
#                           'photo_reference': 'CmRaAAAALzwRyR2GUJV8gAH7cNaFKmThf-XfXpeynLcR0jx3BJccUntiW1eL2xb-ad2HilyqPdmH2_pDTRwdhJhPyUUlyw8h1lFO5dUNCGmJalS0Fz7VMT_JeNo-ZokYfA633sprEhDDjn4tVWAD0_3qp0EuaTJ8GhRc3P61puvm-wjhX_bSUBcKC_9arw',
#                           'width': 3456}],
#               'place_id': 'ChIJf6VTP-qzoQ4RDQfWKNdjjvY',
#               'plus_code': {'compound_code': 'WXQ8+F6 Nouadhibou, Mauritania',
#                             'global_code': '7CG4WXQ8+F6'},
#               'rating': 4.3,
#               'reference': 'ChIJf6VTP-qzoQ4RDQfWKNdjjvY',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 10,
#               'vicinity': 'Unnamed Road'}],
#  'status': 'OK'}

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": "0,0",  # philadelphia coords,
    "type": "lodging",
    "radius": 5000,
    "key": gkey,
}

# use iterrows to iterate through pandas dataframe
for index, row in hotel_df.iterrows():
   
    first = hotel_df.iloc[index,1]
    second = hotel_df.iloc[index,2]
    
    target_coordinates = f"{first},{second}"
    
    # add keyword to params dict
    params['location'] = target_coordinates

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {row[0]}.")
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    try:
        print(f"Closest hotel to {row[0]} is {results[0]['name']}.")
        hotel_df.loc[index, 'hotel name'] = results[0]['name']
        hotel_df.loc[index, 'address'] = results[0]['vicinity']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Retrieving Results for Index 0: nouadhibou.
# Closest hotel to nouadhibou is El Medina.
# ------------
# Retrieving Results for Index 1: portland.
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:844: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Closest hotel to portland is Portland Marriott City Center.
# ------------
# Retrieving Results for Index 2: mount isa.
# Closest hotel to mount isa is ibis Styles Mt Isa Verona.
# ------------
# Retrieving Results for Index 3: bardiyah.
# Closest hotel to bardiyah is بورتو بردية.
# ------------
# Retrieving Results for Index 4: karratha.
# Closest hotel to karratha is ibis Styles Karratha.
# ------------
# Retrieving Results for Index 5: sai buri.
# Closest hotel to sai buri is ร้าน​ เวดดิ้ง.
# ------------
# Retrieving Results for Index 6: benghazi.
# Closest hotel to benghazi is Tibesti Hotel.
# ------------
# Retrieving Results for Index 7: lardos.
# Closest hotel to lardos is Lindos Princess Beach Hotel.
# ------------
# Retrieving Results for Index 8: salamiyah.
# Closest hotel to salamiyah is Gondolas Forum grandchildren and grandparents.
# ------------

# %%
# Out:
#          City    Lat     Lng                                           name  \
# 0  nouadhibou  20.93  -17.03                                      El Medina
# 1    portland  45.52 -122.68                  Portland Marriott City Center
# 2   mount isa -20.73  139.50                      ibis Styles Mt Isa Verona
# 3    bardiyah  31.76   25.09                                    بورتو بردية
# 4    karratha -20.74  116.85                           ibis Styles Karratha
# 5    sai buri   6.70  101.62                                  ร้าน​ เวดดิ้ง
# 6    benghazi  32.12   20.07                                  Tibesti Hotel
# 7      lardos  36.09   28.02                    Lindos Princess Beach Hotel
# 8   salamiyah  35.01   37.05  Gondolas Forum grandchildren and grandparents
#
#                                              address
# 0     zone dubai ext.p5 lot 72. BP. 4350, Nouadhibou
# 1                   520 Southwest Broadway, Portland
# 2      Cnr Rodeo Dr And, Camooweal Street, Mount Isa
# 3                       Unnamed Road, بردية،، بردية،
# 4                     35/45 Searipple Road, Karratha
# 5  อำ​เภ, ถนนบวรวิถี​ ตำ​บล, Taluban, Sai Buri Di...
# 6                                           Benghazi
# 7                                             Lardos
# 8                                          Salamiyah

# %%
hotel_df = hotel_df.rename(columns={"name": "Hotel Name", "address": "Address"})

# %%
hotel_df["Country"] = ideal_cities_df_countries

# %%
hotel_df
# Out:
#          City    Lat     Lng                                     Hotel Name  \
# 0  nouadhibou  20.93  -17.03                                      El Medina
# 1    portland  45.52 -122.68                  Portland Marriott City Center
# 2   mount isa -20.73  139.50                      ibis Styles Mt Isa Verona
# 3    bardiyah  31.76   25.09                                    بورتو بردية
# 4    karratha -20.74  116.85                           ibis Styles Karratha
# 5    sai buri   6.70  101.62                                  ร้าน​ เวดดิ้ง
# 6    benghazi  32.12   20.07                                  Tibesti Hotel
# 7      lardos  36.09   28.02                    Lindos Princess Beach Hotel
# 8   salamiyah  35.01   37.05  Gondolas Forum grandchildren and grandparents
#
#                                              Address Country
# 0     zone dubai ext.p5 lot 72. BP. 4350, Nouadhibou      MR
# 1                   520 Southwest Broadway, Portland      US
# 2      Cnr Rodeo Dr And, Camooweal Street, Mount Isa      AU
# 3                       Unnamed Road, بردية،، بردية،      LY
# 4                     35/45 Searipple Road, Karratha      AU
# 5  อำ​เภ, ถนนบวรวิถี​ ตำ​บล, Taluban, Sai Buri Di...      TH
# 6                                           Benghazi      LY
# 7                                             Lardos      GR
# 8                                          Salamiyah      SY

# %%
#create dataframe to insert the hotel information

# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]
