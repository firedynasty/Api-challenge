# %%
import random
import json
import requests
import pandas as pd
import configparser
import matplotlib.pyplot as plt
from scipy.stats import linregress
from datetime import datetime
from pprint import pprint
config = configparser.ConfigParser()
config.read('../../../API_keys/config.py')
api_key = config['DEFAULT']['api_key']
from citipy import citipy

# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#obtaining the list of cities while generating random numbers
list_of_cities = []
for i in range(0,1300):
    x = random.randrange(-90,90,2)
    y = random.randrange(-180,180, 2) 
    x = x + random.random()
    y = y + random.random()
   # print(x,y)
    city = citipy.nearest_city(x,y)
    list_of_cities.append(city.city_name)

# %%
try_df = pd.DataFrame(list_of_cities)
#making a dataFrame

# %%
try_df[0].value_counts()
#checking for duplicates
# Out:
# rikitea         46
# ushuaia         39
# mataura         27
# punta arenas    24
# busselton       24
#                 ..
# paracuru         1
# zyryanka         1
# tidore           1
# deshna           1
# silvan           1
# Name: 0, Length: 545, dtype: int64

# %% [markdown]
# ## Generate Cities List

# %%
new_df = pd.DataFrame(try_df[0].unique())
#create a new dataframe that only has one value for each city

# %%
new_df
# Out:
#                 0
# 0      chokurdakh
# 1      nikolskoye
# 2           bluff
# 3    punta arenas
# 4            faya
# ..            ...
# 540          buta
# 541     concordia
# 542        preili
# 543       atambua
# 544       nipawin
#
# [545 rows x 1 columns]

# %%
len(new_df)
# Out:
# 545

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
print('Beginning Data Retrieval')
print('------------------------------------')

lat = []
long = []
max_temp = []
humidity = []
cloudiness = []
windspeed = []
country =[]
date = []
city = []
# for index, row in test_df.iterrows():
#     print(row[0])
#     response = requests.get(query_url + row[0]).json()
#     lat.append(response['coord']['lat'])
#     temp.append(response['main']['temp'])
# print(f"The latitude information received is: {lat}")
# print(f"The temperature information received is: {temp}")

for index, row in new_df.iterrows(): 
    query_url = url+ "appid=" + api_key + "&units=" + units + "&q=" + str(row[0])
    response = requests.get(query_url).json()
    try:
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        windspeed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        city.append(row[0])
        print(f'{row[0]} found, processing record {index}') 
    except:
        print('City Not found... skipping')
        pass
# Out:
# Beginning Data Retrieval
# ------------------------------------
# chokurdakh found, processing record 0
# nikolskoye found, processing record 1
# bluff found, processing record 2
# punta arenas found, processing record 3
# faya found, processing record 4
# cefalu found, processing record 5
# trelew found, processing record 6
# victoria found, processing record 7
# ponta do sol found, processing record 8
# sarh found, processing record 9
# tiksi found, processing record 10
# bilma found, processing record 11
# kaitangata found, processing record 12
# asosa found, processing record 13
# tres passos found, processing record 14
# tilichiki found, processing record 15
# kruisfontein found, processing record 16
# muroto found, processing record 17
# iqaluit found, processing record 18
# bubaque found, processing record 19
# thompson found, processing record 20
# City Not found... skipping
# dawson creek found, processing record 22
# jamestown found, processing record 23
# demba found, processing record 24
# hofn found, processing record 25
# esperance found, processing record 26
# along found, processing record 27
# kodiak found, processing record 28
# mahebourg found, processing record 29
# khatanga found, processing record 30
# geraldton found, processing record 31
# torbay found, processing record 32
# tasiilaq found, processing record 33
# bathsheba found, processing record 34
# sitka found, processing record 35
# City Not found... skipping
# kudymkar found, processing record 37
# east london found, processing record 38
# west bay found, processing record 39
# nahavand found, processing record 40
# puerto ayora found, processing record 41
# hami found, processing record 42
# saint-philippe found, processing record 43
# castro found, processing record 44
# tuktoyaktuk found, processing record 45
# City Not found... skipping
# kamenka found, processing record 47
# rikitea found, processing record 48
# tual found, processing record 49
# hermanus found, processing record 50
# cavalcante found, processing record 51
# nouadhibou found, processing record 52
# lagoa found, processing record 53
# lavrentiya found, processing record 54
# saint george found, processing record 55
# prince rupert found, processing record 56
# mataura found, processing record 57
# san vicente de canete found, processing record 58
# matara found, processing record 59
# cape town found, processing record 60
# cabo san lucas found, processing record 61
# pelaya found, processing record 62
# gonbad-e qabus found, processing record 63
# pisco found, processing record 64
# airai found, processing record 65
# City Not found... skipping
# tura found, processing record 67
# arraial do cabo found, processing record 68
# bonthe found, processing record 69
# busselton found, processing record 70
# south lake tahoe found, processing record 71
# severo-kurilsk found, processing record 72
# grindavik found, processing record 73
# praia da vitoria found, processing record 74
# barrow found, processing record 75
# City Not found... skipping
# redwater found, processing record 77
# pital found, processing record 78
# atuona found, processing record 79
# City Not found... skipping
# esso found, processing record 81
# palmer found, processing record 82
# City Not found... skipping
# provideniya found, processing record 84
# saint-vallier found, processing record 85
# flin flon found, processing record 86
# ushuaia found, processing record 87
# carnarvon found, processing record 88
# City Not found... skipping
# bambous virieux found, processing record 90
# hobart found, processing record 91
# katsuura found, processing record 92
# City Not found... skipping
# lompoc found, processing record 94
# City Not found... skipping
# City Not found... skipping
# cidreira found, processing record 97
# yenagoa found, processing record 98
# tricase found, processing record 99
# gao found, processing record 100
# westport found, processing record 101
# qaanaaq found, processing record 102
# nhulunbuy found, processing record 103
# cuiluan found, processing record 104
# oktyabrskiy found, processing record 105
# saskylakh found, processing record 106
# la ronge found, processing record 107
# new norfolk found, processing record 108
# koumac found, processing record 109
# coolum beach found, processing record 110
# savannah bight found, processing record 111
# olinda found, processing record 112
# saint-francois found, processing record 113
# zhigansk found, processing record 114
# bedele found, processing record 115
# tanete found, processing record 116
# hamilton found, processing record 117
# pevek found, processing record 118
# port hueneme found, processing record 119
# ostrovnoy found, processing record 120
# vaini found, processing record 121
# chicama found, processing record 122
# baijiantan found, processing record 123
# avera found, processing record 124
# mayo found, processing record 125
# sao felix do xingu found, processing record 126
# porbandar found, processing record 127
# bethel found, processing record 128
# kappeln found, processing record 129
# mehamn found, processing record 130
# usogorsk found, processing record 131
# smithers found, processing record 132
# City Not found... skipping
# mar del plata found, processing record 134
# kurilsk found, processing record 135
# jacareacanga found, processing record 136
# sao joao da barra found, processing record 137
# touros found, processing record 138
# belmonte found, processing record 139
# hithadhoo found, processing record 140
# florianopolis found, processing record 141
# avarua found, processing record 142
# jiwani found, processing record 143
# praia found, processing record 144
# City Not found... skipping
# ilulissat found, processing record 146
# portland found, processing record 147
# fairbanks found, processing record 148
# college found, processing record 149
# yaan found, processing record 150
# albany found, processing record 151
# burns lake found, processing record 152
# City Not found... skipping
# haines junction found, processing record 154
# tuatapere found, processing record 155
# bandiagara found, processing record 156
# georgetown found, processing record 157
# karasburg found, processing record 158
# hitachi found, processing record 159
# sorland found, processing record 160
# upernavik found, processing record 161
# City Not found... skipping
# City Not found... skipping
# damara found, processing record 164
# port alfred found, processing record 165
# pucallpa found, processing record 166
# okhotsk found, processing record 167
# City Not found... skipping
# roma found, processing record 169
# mount isa found, processing record 170
# okakarara found, processing record 171
# longyearbyen found, processing record 172
# sheregesh found, processing record 173
# dikson found, processing record 174
# sola found, processing record 175
# saryozek found, processing record 176
# vicksburg found, processing record 177
# polangi found, processing record 178
# hilo found, processing record 179
# sinnamary found, processing record 180
# City Not found... skipping
# elektrenai found, processing record 182
# kavieng found, processing record 183
# fergus falls found, processing record 184
# bengkulu found, processing record 185
# elizabeth city found, processing record 186
# margate found, processing record 187
# warrington found, processing record 188
# City Not found... skipping
# ancud found, processing record 190
# kununurra found, processing record 191
# lagos found, processing record 192
# jitra found, processing record 193
# naze found, processing record 194
# dondo found, processing record 195
# isangel found, processing record 196
# marzuq found, processing record 197
# bosaso found, processing record 198
# yellowknife found, processing record 199
# preobrazheniye found, processing record 200
# honiara found, processing record 201
# chuy found, processing record 202
# hof found, processing record 203
# maceio found, processing record 204
# bardiyah found, processing record 205
# batouri found, processing record 206
# san patricio found, processing record 207
# ames found, processing record 208
# aklavik found, processing record 209
# nyurba found, processing record 210
# talnakh found, processing record 211
# pimentel found, processing record 212
# moron found, processing record 213
# olafsvik found, processing record 214
# mikuni found, processing record 215
# City Not found... skipping
# alice springs found, processing record 217
# City Not found... skipping
# nalut found, processing record 219
# auki found, processing record 220
# City Not found... skipping
# urumqi found, processing record 222
# northam found, processing record 223
# broome found, processing record 224
# City Not found... skipping
# srednekolymsk found, processing record 226
# peniche found, processing record 227
# sovetskaya gavan found, processing record 228
# bredasdorp found, processing record 229
# sobolevo found, processing record 230
# lorengau found, processing record 231
# port elizabeth found, processing record 232
# oussouye found, processing record 233
# leningradskiy found, processing record 234
# satao found, processing record 235
# hualmay found, processing record 236
# san carlos de bariloche found, processing record 237
# kotelnich found, processing record 238
# kapaa found, processing record 239
# conde found, processing record 240
# luderitz found, processing record 241
# lebu found, processing record 242
# vila found, processing record 243
# nemuro found, processing record 244
# karratha found, processing record 245
# meulaboh found, processing record 246
# buchanan found, processing record 247
# ternate found, processing record 248
# port moresby found, processing record 249
# novaky found, processing record 250
# daru found, processing record 251
# quang ngai found, processing record 252
# leshukonskoye found, processing record 253
# mossendjo found, processing record 254
# port macquarie found, processing record 255
# igarka found, processing record 256
# ribeira grande found, processing record 257
# rafraf found, processing record 258
# salalah found, processing record 259
# kupang found, processing record 260
# buraydah found, processing record 261
# tame found, processing record 262
# severomuysk found, processing record 263
# dzhubga found, processing record 264
# port lincoln found, processing record 265
# kerrobert found, processing record 266
# killarney found, processing record 267
# roanne found, processing record 268
# barcelona found, processing record 269
# uyar found, processing record 270
# sao filipe found, processing record 271
# varva found, processing record 272
# new port richey found, processing record 273
# kirsanov found, processing record 274
# mayumba found, processing record 275
# hervey bay found, processing record 276
# togur found, processing record 277
# rio gallegos found, processing record 278
# west wendover found, processing record 279
# bulawayo found, processing record 280
# sai buri found, processing record 281
# City Not found... skipping
# vostok found, processing record 283
# sulangan found, processing record 284
# egvekinot found, processing record 285
# beian found, processing record 286
# majene found, processing record 287
# dongkan found, processing record 288
# chifeng found, processing record 289
# marawi found, processing record 290
# svetlyy found, processing record 291
# husavik found, processing record 292
# inhambane found, processing record 293
# souillac found, processing record 294
# sept-iles found, processing record 295
# jalu found, processing record 296
# alofi found, processing record 297
# borborema found, processing record 298
# praya found, processing record 299
# fortuna found, processing record 300
# chumikan found, processing record 301
# prieska found, processing record 302
# tocopilla found, processing record 303
# voh found, processing record 304
# fort nelson found, processing record 305
# camacha found, processing record 306
# rawson found, processing record 307
# cayenne found, processing record 308
# xam nua found, processing record 309
# moratuwa found, processing record 310
# guanica found, processing record 311
# alta floresta found, processing record 312
# City Not found... skipping
# acapulco found, processing record 314
# narsaq found, processing record 315
# yumaguzino found, processing record 316
# coquimbo found, processing record 317
# san jose found, processing record 318
# City Not found... skipping
# aberfeldy found, processing record 320
# nizwa found, processing record 321
# halkirk found, processing record 322
# nampula found, processing record 323
# yekaterinovka found, processing record 324
# townsville found, processing record 325
# hailey found, processing record 326
# mount gambier found, processing record 327
# high level found, processing record 328
# xiongyue found, processing record 329
# mantua found, processing record 330
# campbell river found, processing record 331
# brejo santo found, processing record 332
# shieli found, processing record 333
# saint-joseph found, processing record 334
# kysyl-syr found, processing record 335
# nanortalik found, processing record 336
# namikupa found, processing record 337
# City Not found... skipping
# ilhabela found, processing record 339
# codrington found, processing record 340
# rey bouba found, processing record 341
# City Not found... skipping
# bileca found, processing record 343
# nahariyya found, processing record 344
# puerto escondido found, processing record 345
# salinopolis found, processing record 346
# jawhar found, processing record 347
# taiobeiras found, processing record 348
# puerto el triunfo found, processing record 349
# pangody found, processing record 350
# lodja found, processing record 351
# butaritari found, processing record 352
# karpogory found, processing record 353
# City Not found... skipping
# mackay found, processing record 355
# homer found, processing record 356
# mae hong son found, processing record 357
# contamana found, processing record 358
# linxia found, processing record 359
# lasa found, processing record 360
# porto de moz found, processing record 361
# kasongo-lunda found, processing record 362
# lokosovo found, processing record 363
# jenison found, processing record 364
# aknada found, processing record 365
# safford found, processing record 366
# sri aman found, processing record 367
# manta found, processing record 368
# City Not found... skipping
# port blair found, processing record 370
# kudat found, processing record 371
# bayan found, processing record 372
# lethem found, processing record 373
# clyde river found, processing record 374
# san cristobal found, processing record 375
# oranjestad found, processing record 376
# comodoro rivadavia found, processing record 377
# darlowo found, processing record 378
# port hardy found, processing record 379
# piracanjuba found, processing record 380
# aqtobe found, processing record 381
# gizo found, processing record 382
# City Not found... skipping
# acarau found, processing record 384
# barber found, processing record 385
# sistranda found, processing record 386
# ferme-neuve found, processing record 387
# erzin found, processing record 388
# pakhtakoron found, processing record 389
# am timan found, processing record 390
# lambarene found, processing record 391
# City Not found... skipping
# imbituba found, processing record 393
# komsomolskiy found, processing record 394
# san andres found, processing record 395
# City Not found... skipping
# neuquen found, processing record 397
# moindou found, processing record 398
# boa vista found, processing record 399
# quatre cocos found, processing record 400
# City Not found... skipping
# lugovoy found, processing record 402
# hovd found, processing record 403
# saldanha found, processing record 404
# fort saint james found, processing record 405
# huilong found, processing record 406
# paracuru found, processing record 407
# morro bay found, processing record 408
# chernyshevskiy found, processing record 409
# jaicos found, processing record 410
# coihaique found, processing record 411
# roald found, processing record 412
# silivri found, processing record 413
# camacupa found, processing record 414
# estreito found, processing record 415
# dawlatabad found, processing record 416
# tahta found, processing record 417
# nizhnyaya maktama found, processing record 418
# ahipara found, processing record 419
# umm kaddadah found, processing record 420
# maine-soroa found, processing record 421
# derzhavinsk found, processing record 422
# benghazi found, processing record 423
# mamallapuram found, processing record 424
# yumen found, processing record 425
# banda aceh found, processing record 426
# bam found, processing record 427
# archidona found, processing record 428
# ola found, processing record 429
# kenai found, processing record 430
# tehri found, processing record 431
# City Not found... skipping
# bataipora found, processing record 433
# mecca found, processing record 434
# kavaratti found, processing record 435
# yulara found, processing record 436
# dingle found, processing record 437
# celestun found, processing record 438
# qasigiannguit found, processing record 439
# monrovia found, processing record 440
# shouguang found, processing record 441
# City Not found... skipping
# City Not found... skipping
# lardos found, processing record 444
# huanren found, processing record 445
# plainview found, processing record 446
# City Not found... skipping
# labuhan found, processing record 448
# City Not found... skipping
# srandakan found, processing record 450
# chivilcoy found, processing record 451
# marystown found, processing record 452
# ukiah found, processing record 453
# xining found, processing record 454
# kedrovyy found, processing record 455
# vrangel found, processing record 456
# sarakhs found, processing record 457
# mahanoro found, processing record 458
# salamiyah found, processing record 459
# pereslavl-zalesskiy found, processing record 460
# ardakan found, processing record 461
# port hedland found, processing record 462
# constitucion found, processing record 463
# krasnoselkup found, processing record 464
# camalu found, processing record 465
# segamat found, processing record 466
# holovyne found, processing record 467
# nazarovo found, processing record 468
# oum hadjer found, processing record 469
# zhangjiakou found, processing record 470
# dunedin found, processing record 471
# vao found, processing record 472
# merrill found, processing record 473
# City Not found... skipping
# meiringen found, processing record 475
# norman wells found, processing record 476
# chapada dos guimaraes found, processing record 477
# santa isabel found, processing record 478
# ayagoz found, processing record 479
# faanui found, processing record 480
# baruun-urt found, processing record 481
# medak found, processing record 482
# guerrero negro found, processing record 483
# khonsa found, processing record 484
# cosereni found, processing record 485
# chichli found, processing record 486
# kloulklubed found, processing record 487
# City Not found... skipping
# tongliao found, processing record 489
# santander found, processing record 490
# maniitsoq found, processing record 491
# nishihara found, processing record 492
# maragogi found, processing record 493
# catamarca found, processing record 494
# silvan found, processing record 495
# ust-tsilma found, processing record 496
# ulladulla found, processing record 497
# svetlogorsk found, processing record 498
# jumla found, processing record 499
# san pedro found, processing record 500
# rocha found, processing record 501
# mizque found, processing record 502
# yiyang found, processing record 503
# slobodskoy found, processing record 504
# san quintin found, processing record 505
# casambalangan found, processing record 506
# aykhal found, processing record 507
# pochutla found, processing record 508
# City Not found... skipping
# killybegs found, processing record 510
# sibu found, processing record 511
# luena found, processing record 512
# tyukalinsk found, processing record 513
# imeni poliny osipenko found, processing record 514
# reconquista found, processing record 515
# sorong found, processing record 516
# trairi found, processing record 517
# dabwali found, processing record 518
# toktogul found, processing record 519
# zyryanka found, processing record 520
# groningen found, processing record 521
# yerbogachen found, processing record 522
# ormara found, processing record 523
# City Not found... skipping
# chara found, processing record 525
# City Not found... skipping
# torit found, processing record 527
# ghanzi found, processing record 528
# City Not found... skipping
# oyama found, processing record 530
# jacksonville found, processing record 531
# san ignacio found, processing record 532
# gigmoto found, processing record 533
# huarmey found, processing record 534
# riyadh found, processing record 535
# City Not found... skipping
# pasuruan found, processing record 537
# meadow lake found, processing record 538
# catuday found, processing record 539
# buta found, processing record 540
# concordia found, processing record 541
# preili found, processing record 542
# atambua found, processing record 543
# nipawin found, processing record 544

# %%
data = {"City":city,"Lat":lat,"Lng":long,"Max Temp":max_temp,"Humidity":humidity,"Cloudiness":cloudiness,
        "Wind Speed":windspeed,"Country":country,"Date":date}

# %%
len(lat)
#number of cities in the dataframe
# Out:
# 499

# %%
cities_info_df = pd.DataFrame(data)
cities_info_df
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      chokurdakh  70.63  147.92     34.95        96          38       14.94
# 1      nikolskoye  59.70   30.79     55.40        82          20        6.71
# 2           bluff -46.60  168.33     37.99        94          61        3.00
# 3    punta arenas -53.15  -70.92     37.40        59          75       35.57
# 4            faya  18.39   42.45     69.80        64          14        5.82
# ..            ...    ...     ...       ...       ...         ...         ...
# 494          buta   2.79   24.73     71.64        96          94        2.21
# 495     concordia -31.39  -58.02     84.00        50          48       10.00
# 496        preili  56.29   26.72     53.15        84          85        7.65
# 497       atambua  -9.11  124.89     72.32        79          21        2.86
# 498       nipawin  53.37 -104.00     44.60        70          90       19.46
#
#     Country        Date
# 0        RU  1601488077
# 1        RU  1601488077
# 2        NZ  1601488077
# 3        CL  1601487894
# 4        SA  1601488078
# ..      ...         ...
# 494      CD  1601488214
# 495      AR  1601488268
# 496      LV  1601488269
# 497      ID  1601488269
# 498      CA  1601488088
#
# [499 rows x 9 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_info_df.describe()
# Out:
#               Lat         Lng    Max Temp   Humidity  Cloudiness  Wind Speed  \
# count  511.000000  511.000000  511.000000  511.00000  511.000000  511.000000
# mean    20.787671   15.928748   64.505382   70.44227   50.048924    8.611370
# std     34.702387   91.343090   18.537221   20.80102   36.655625    6.158711
# min    -54.800000 -179.170000   14.340000    1.00000    0.000000    0.180000
# 25%     -8.300000  -63.575000   51.160000   59.00000   14.000000    3.870000
# 50%     24.700000   21.550000   66.990000   75.00000   47.000000    6.930000
# 75%     52.115000   93.875000   79.040000   85.00000   85.500000   11.420000
# max     78.220000  178.420000  107.550000  100.00000  100.000000   35.570000
#
#                Date
# count  5.110000e+02
# mean   1.601483e+09
# std    8.641042e+01
# min    1.601483e+09
# 25%    1.601483e+09
# 50%    1.601483e+09
# 75%    1.601483e+09
# max    1.601483e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
cities_info_df.loc[cities_info_df["Humidity"]>100]
#  Get the indices of cities that have humidity over 100%.
# No cities with humidity over 100
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
cities_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        499 non-null    object
#  1   Lat         499 non-null    float64
#  2   Lng         499 non-null    float64
#  3   Max Temp    499 non-null    float64
#  4   Humidity    499 non-null    int64
#  5   Cloudiness  499 non-null    int64
#  6   Wind Speed  499 non-null    float64
#  7   Country     499 non-null    object
#  8   Date        499 non-null    int64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 35.2+ KB

# %%
cities_info_df.plot(kind="scatter", x="Lat", y="Max Temp", grid=True, figsize=(6,6), edgecolors="black",
                    title="City Latitude vs. Max Temperature 9/30/20")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
cities_info_df.plot(kind="scatter", x="Lat", y="Humidity", grid=True, figsize=(6,6), edgecolors="black",
                    title="City Latitude vs. Humidity 9/30/20")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
cities_info_df.plot(kind="scatter", x="Lat", y="Cloudiness", grid=True, figsize=(6,6), edgecolors="black",
                    title="City Latitude vs. Cloudiness 9/30/20")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
cities_info_df.plot(kind="scatter", x="Lat", y="Wind Speed", grid=True, figsize=(6,6), edgecolors="black",
                    title="City Latitude vs. Cloudiness 9/30/20")

# %% [markdown]
# ## Linear Regression

# %%
cities_info_df.plot(kind="scatter", x="Lat", y="Max Temp", grid=True, figsize=(6,6), edgecolors="black",
                    title="City Latitude vs. Max Temperature 9/30/20")

# %%
Northern_cities_df = cities_info_df.loc[cities_info_df["Lat"] > 0]
Southern_cities_df = cities_info_df.loc[cities_info_df["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
cities_info_df

# %%
# Add the linear regression equation and line to plot
x_values = Northern_cities_df["Lat"]
y_values = Northern_cities_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Northern Hemisphere Lat vs. Max Temp 9/30/20')
print(f"The r-squared is {rvalue**2}")
plt.show()
# Out:
# The r-squared is 0.713755077910701

# %%
# Add the linear regression equation and line to plot
x_values = Southern_cities_df["Lat"]
y_values = Southern_cities_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Southern Hemisphere vs. Max Temp 9/30/20')
print(f"The r-squared is {rvalue**2}")
print(f'The line equation is {line_eq}')
plt.show()
# Out:
# The r-squared is 0.46584173795554124
# The line equation is y = 0.79x + 88.71

# %%
x_values = Northern_cities_df["Lat"]
y_values = Northern_cities_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Northern Hemisphere Lat vs. Humidity 9/30/20')
print(f"The r-squared is {rvalue**2}")
plt.show()
# Out:
# The r-squared is :0.02570690444286322

# %%
# Add the linear regression equation and line to plot
x_values = Southern_cities_df["Lat"]
y_values = Southern_cities_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Southern Hemisphere Lat vs. Humidity 9/30/20')
print(f"The r-squared is {rvalue**2}")
print(f'The line equation is {line_eq}')
plt.show()
# Out:
# The r-squared is 0.0001818264350725559
# The line equation is y = 0.02x + 64.29

# %%
x_values = Northern_cities_df["Lat"]
y_values = Northern_cities_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere Lat vs. Cloudiness 9/30/20')
print(f"The r-squared is {rvalue**2}")
plt.show()
# Out:
# The r-squared is 0.0049060572459219175

# %%
# Add the linear regression equation and line to plot
x_values = Southern_cities_df["Lat"]
y_values = Southern_cities_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Southern Hemisphere Lat vs. Cloudiness 9/30/20')
print(f"The r-squared is {rvalue**2}")
print(f'The line equation is {line_eq}')

plt.show()
# Out:
# The r-squared is 0.04599500524121952
# The line equation is y = 0.52x + 53.61

# %%
x_values = Northern_cities_df["Lat"]
y_values = Northern_cities_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Northern Hemisphere Lat vs. Wind Speed 9/30/20')
print(f"The r-squared is {rvalue**2}")
plt.show()
# Out:
# The r-squared is 0.014045145805490595

# %%
x_values = Southern_cities_df["Lat"]
y_values = Southern_cities_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Southern Hemisphere Lat vs. Wind Speed 9/30/20')
print(f"The r-squared is {rvalue**2}")
print(f'The line equation is {line_eq}')
plt.show()
# Out:
# The r-squared is 0.04145816813488419
# The line equation is y = -0.11x + 8.1
